# %% [markdown]
# #  Python for Economic and Social Data Science
#
# ## 16th July, 2024
# ---
# ## Homework Two

# %% [markdown]
# ## Question One: Len
#
# Using ```split``` and ```len```, figure out how to compute how many words are in this famous quote by Albert Einstein:
#
# ```python
# albert_einstein = 'Logic will get you from A to Z, but imagination will take you everywhere.'
# ```

# %%
albert_einstein = 'Logic will get you from A to Z, but imagination will take you everywhere.'
words =albert_einstein.split()
number_of_words =len(words)
print(number_of_words)
# Out:
# 14

# %% [markdown]
# ## Question Two: Letters in set
#
# Here are two lines of lyrics to a [great song](https://www.youtube.com/watch?v=lPYOeOra-JI):
#
# ```python
# nownow1 = "Stuck like those prehistoric mammoths in the ice"
# nownow2 = "Thaw me out and I won't close my eyes"
# ```
#
# Using a set, count the number of unique letters in nownow1. S and s should count as the same.

# %%
# Answer Two here
nownow1 = "Stuck like those prehistoric mammoths in the ice"

unique_letters= set(nownow1.lower())
unique_letters.remove(' ')
number_of_unique_letters= len(unique_letters)
print(number_of_unique_letters)
# Out:
# 15

# %% [markdown]
# ## Question Three: Overlapping Sets
#
# Print the unique letters that are in (the set of) nownow1 AND nownow2

# %%
# Answer Three here
nownow1 = "Stuck like those prehistoric mammoths in the ice"
nownow2 = "Thaw me out and I won't close my eyes"

#set1 =set(nownow1.lower())
#'set1.remove(' ')
#set2 =set(nownow2.lower())
#set2.remove(' ')
#common_letters =set1.intersection(set2)
#common_letters_list =sorted(list(common_letters))
#print(common_letters_list)

common_set = set(" ".join[nownow1.lower()+nownow2.lower()])
#common_set.remove(' ')
#common_set.remove("'")
#common_set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 13
#       3 nownow2 = "Thaw me out and I won't close my eyes"
#       5 #set1 =set(nownow1.lower())
#       6 #'set1.remove(' ')
#       7 #set2 =set(nownow2.lower())
#    (...)
#      10 #common_letters_list =sorted(list(common_letters))
#      11 #print(common_letters_list)
# ---> 13 common_set = set(" ".join[nownow1.lower()+nownow2.lower()])
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %% [markdown]
# ## Question Four: Overlapping Sets
#
# ```python
# wrongphrase = "The slow red fox sat by the friendly dog"
# ```
#
# Print the right phrase ("The quick brown fox jumps over the lazy dog") by splitting, replacing the wrong words with the right ones, and then (re-)joining:

# %%
# Answer Four here
wrongphrase = "The slow red fox sat by the friendly dog"
words= wrongphrase.split()
correct_words ={"slow": "quick", "red":"brown", "sat":"jumps", "by":"over", "friendly":"lazy"}
corrected_words=[correct_words[word] if word in correct_words else word for word in words]
#correctphrase= " ".join(corrected_words)
#print(correctphrase)
print(words)
print(correct_words)
print(corrected_words)
# Out:
# ['The', 'slow', 'red', 'fox', 'sat', 'by', 'the', 'friendly', 'dog']
# {'slow': 'quick', 'red': 'brown', 'sat': 'jumps', 'by': 'over', 'friendly': 'lazy'}
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %% [markdown]
# ## Question Five: Overlapping Sets
#
# Loop through [the words](https://soundcloud.com/leahkardos/leah-kardos-dface-practice): if the word starts with an 'a', then print it:
#
# ```python
# practicethis = "The object of this lesson is to internalise the notes and the keys; in other words, it should become like a reflex for you to see the note on the page and immediately play that appropriate key, in the same way that you see a letter in a word, and immediately visualise the pronounciation."
# ```

# %%
# Answer Five here
practicethis = "The object of this lesson is to internalise the notes and the keys; in other words, it should become like a reflex for you to see the note on the page and immediately play that appropriate key, in the same way that you see a letter in a word, and immediately visualise the pronounciation."
words=practicethis.split()
for word in words:
    if word[0]=='a':
        print(word)
# Out:
# and
# a
# and
# appropriate
# a
# a
# and

# %% [markdown]
# ## Question Six: Dictionary Replacement
#
# a_descriptive_phrase = "My name is Willy Loman and I am a salesman."
#
# ```python
# about_you = {
#     "Willy Loman":"your name",
#     "salesman":"your profession",
# }
# ```
# Print the correct phrase using the dictionary to replace the wrong words with the right ones. This will require you to split the phrase, use the dictionary above to replace the words. Then join the phrase together, then print it. (please feel free to change the dictionary values to anything you like!)

# %%
# Answer Six here
a_descriptive_phrase = "My name is Willy Loman and I am a salesman."

###about_you = {
#    "First name":"Yanan",
#    "Surname name":"Zhang",
#    "your profession":"Researcher",
#}
#
#list_a_descriptive_phrase=a_descriptive_phrase.split(' ')
#list_a_descriptive_phrase[3]=about_you['First name']
#list_a_descriptive_phrase[4]=about_you['Surname name']
#list_a_descriptive_phrase[9]=about_you['your profession']

#' '.join(list_a_descriptive_phrase)

a_descriptive_phrase = a_descriptive_phrase.replace('Willy Loman', 'Yanan Zhang')
a_descriptive_phrase
# Out:
# 'My name is Yanan Zhang and I am a salesman.'

# %% [markdown]
# ## Question Seven: For loops and if conditions
#
# The for loop below will run 10 times generating a random number each time. If the number is odd, multiply the number by two and then print a warning and the number on the same line. If the number is greater than 4, you should also print some words of wisdom (be creative!) on the same line as the (new) number. Here's a bit of code to get you started:
#
# ```python
# import random
# for i in range(10):
#     rando = random.randint(0,9)
# ```

# %%
# Answer Seven here
import random
for i in range(10):
    rando = random.randint(0,9)
    if rando%2==1:
        num=rando*2
        print(num,'can not be divided by two')
    if rando >4:
        print(rando, 'larger than 4')
# Out:
# 8 larger than 4
# 8 larger than 4
# 2 can not be divided by two
# 6 can not be divided by two
# 18 can not be divided by two
# 9 larger than 4
# 6 larger than 4
# 6 larger than 4
# 6 larger than 4

# %% [markdown]
# ## Question Eight: For loops and if conditions
#
# Print a number UNLESS it has already been printed. Here's a bit of code to get you started:
#
# ```python
# import random
# for i in range(10):
#     rando = random.randint(0,9)
# ```

# %%
# Answer Eight here
import random
a = []
for i in range(10):
    rando = random.randint(0,9)
    if rando not in a:
        print(rando)
        a.append(rando)
    else:
        pass
# Out:
# 6
# 3
# 0
# 5
# 4

# %% [markdown]
# ## Question Nine: List Comprehension
#
# Write the following as a list comprehension:
#
# ```python
# pwrs = []
# for i in range(0,10):
#     pwrs.append(i**i)
# print(pwrs)
# ```

# %%
# Answer Nine here
pwrs = []
[pwrs.append(i ** i) for i in range(0,10) ]
print(pwrs)
# Out:
# [1, 1, 4, 27, 256, 3125, 46656, 823543, 16777216, 387420489]

# %% [markdown]
# ### Question Ten: List Comprehension Cont
#
# Write the following as a list comprehension which contains an if condition:
#
# ```
# Tweet = "Who’s Who study sheds new light on power of old boy network - great study by @SamFriedmanSoc @aaronsreeves @LSEnews"
# ```
#
# ```python
# AtMentions = []
# for i in Tweet.split():
#     if i[0] == '@':
#         AtMentions.append(i)
# print(AtMentions)
# ```

# %%
# Answer Ten here

Tweet = "Who’s Who study sheds new light on power of old boy network - great study by @SamFriedmanSoc @aaronsreeves @LSEnews"
AtMentions = []
[AtMentions.append(i)for i in Tweet.split() if i[0] == '@' ]
print(AtMentions)
# Out:
# ['@SamFriedmanSoc', '@aaronsreeves', '@LSEnews']
