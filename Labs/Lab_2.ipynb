# %% [markdown]
# # Python for Health, Social, and Economic Data Science

# %% [markdown]
# ## Lab 2: Iteration, Logic, and Error Handling
#
# This lab extends Lecture 2 with health, social, and economic data-science examples.
#
# Rules:
# - Use clear variable names and readable code.
# - Print intermediate outputs so your logic is easy to follow.
# - Reuse objects where possible rather than rewriting from scratch.

# %% [markdown]
# ## Part A: Strings, Sets, and Basic Text Processing (Approx. 35 minutes)

# %% [markdown]
# ### Question 1: Len
#
# Using `split` and `len`, compute how many words are in this short policy statement:
#
# ```python
# policy_statement = 'Integrated health social and economic policy improves long term wellbeing outcomes.'
# ```

# %%
# Answer 1

# %% [markdown]
# ### Question 2: Letters in set
#
# Here are two short lines from a neighbourhood monitoring report:
#
# ```python
# report_line1 = "Clinic visits are rising in Northside"
# report_line2 = "School absence is falling in Central"
# ```
#
# Using a set, count the number of unique letters in `report_line1`. Upper and lower case should count as the same.

# %%
# Answer 2

# %% [markdown]
# ### Question 3: Overlapping Sets
#
# Print the unique letters that appear in **both** `report_line1` and `report_line2`.

# %%
# Answer 3

# %% [markdown]
# ### Question 4: Phrase Repair with split/replace/join
#
# ```python
# wrongphrase = "Northside low clinic visits and high school attendance"
# ```
#
# Print the corrected phrase:
# `Northside high clinic visits and low school attendance`
#
# Do this by splitting, replacing the incorrect words, and re-joining.

# %%
# Answer 4

# %% [markdown]
# ### Question 5: Loop Through Words with a Condition
#
# Loop through the words in the text below. If a word starts with `u`, print it:
#
# ```python
# analysis_text = "Urban unemployment usually increases uncertainty unless urgent support is available"
# ```

# %%
# Answer 5

# %% [markdown]
# ### Question 6: Dictionary Replacement
#
# ```python
# a_descriptive_phrase = "My area is Northside and my role is analyst."
#
# about_you = {
#     "Northside": "your area",
#     "analyst": "your role",
# }
# ```
#
# Print the corrected phrase by replacing the placeholder values using the dictionary.
#
# You will need to split the phrase, replace values, then join and print it.

# %%
# Answer 6

# %% [markdown]
# ## Part B: Loops, Comprehensions, and Conditions (Approx. 40 minutes)

# %% [markdown]
# ### Question 7: For loops and if conditions
#
# The loop below runs 10 times and generates a random risk score each time.
#
# If the score is odd, multiply it by 2 and print a warning plus the new score.
# If the (possibly updated) score is greater than 4, also print a short message about reviewing health/social/economic risk.
#
# ```python
# import random
# for i in range(10):
#     risk_score = random.randint(0, 9)
# ```

# %%
# Answer 7

# %% [markdown]
# ### Question 8: For loops and if conditions
#
# Simulate random area codes (0-9), but print a code only if it has not already been printed.
#
# Starter code:
#
# ```python
# import random
# for i in range(10):
#     area_code = random.randint(0, 9)
# ```

# %%
# Answer 8

# %% [markdown]
# ### Question 9: List Comprehension
#
# Rewrite the loop below as a list comprehension.
#
# Interpretation: this creates a simple nonlinear index from baseline risk scores.
#
# ```python
# risk_index = []
# for i in range(0, 10):
#     risk_index.append(i**i)
# print(risk_index)
# ```

# %%
# Answer 9

# %% [markdown]
# ### Question 10: List Comprehension Continued
#
# Rewrite the following as a list comprehension with an if condition:
#
# ```python
# Update = "New analysis by @HealthUnit @CityDataLab and @PolicyGroup links income shocks to school absence"
# ```
#
# ```python
# AtMentions = []
# for i in Update.split():
#     if i[0] == '@':
#         AtMentions.append(i)
# print(AtMentions)
# ```

# %%
# Answer 10

# %% [markdown]
# ## Part C: Dictionaries and Error Handling (Approx. 35 minutes)

# %% [markdown]
# ### Question 11: Set Operations on Indicators
#
# Given:
#
# ```python
# health_indicators = {"clinic_visits", "hospital_wait_time", "vaccination_rate"}
# economic_indicators = {"median_income", "unemployment_rate", "vaccination_rate"}
# ```
#
# Print:
# 1. The union of both sets
# 2. The intersection of both sets
# 3. Indicators in `health_indicators` but not in `economic_indicators`

# %%
# Answer 11

# %% [markdown]
# ### Question 12: Dictionary Iteration and Classification
#
# Given:
#
# ```python
# area_income = {"Northside": 29000, "Central": 36000, "Riverside": 25000}
# ```
#
# Loop through the dictionary and print each area with:
# - `high income` if the value is at least 30000
# - `lower income` otherwise

# %%
# Answer 12

# %% [markdown]
# ### Question 13: Nested Dictionary Checks
#
# Given:
#
# ```python
# area_snapshot = {
#     "Northside": {"clinic_visits": 120, "school_absence_rate": 0.07},
#     "Central": {"clinic_visits": 95, "school_absence_rate": 0.05},
#     "Riverside": {"clinic_visits": 140, "school_absence_rate": 0.09}
# }
# ```
#
# Loop through each area and print a warning if:
# - `clinic_visits` is above 130, or
# - `school_absence_rate` is above 0.08

# %%
# Answer 13

# %% [markdown]
# ### Question 14: List Comprehension with Dictionaries
#
# Given:
#
# ```python
# records = [
#     {"area": "Northside", "median_income": 29000},
#     {"area": "Central", "median_income": 36000},
#     {"area": "Riverside", "median_income": 25000}
# ]
# ```
#
# Write a list comprehension that creates `lower_income_areas`, containing only area names where `median_income < 30000`.

# %%
# Answer 14

# %% [markdown]
# ### Question 15: Error Handling in Data Cleaning
#
# Given:
#
# ```python
# raw_visits = ["120", "95", "missing", "140", "error", "102"]
# ```
#
# Use a loop with `try/except` to:
# 1. Convert valid values to integers and append to `clean_visits`
# 2. Skip invalid values with a short printed message
# 3. Print `clean_visits` at the end

# %%
# Answer 15

# %% [markdown]
# ## Stretch (Optional)
#
# Create one additional mini-question of your own that combines:
# - a loop or comprehension
# - a dictionary or set
# - one health, social, or economic context variable
#
# Write 2-3 lines on why your question is useful for data cleaning or policy analysis.
