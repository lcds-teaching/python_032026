# %% [markdown]
# # Python for Health, Social, and Economic Data Science
#
# ## Lab 5: Applied Modelling with StatsModels, Scikit-learn, and Text Data
#
# This lab is based directly on Lecture 5. It is heavily focused on modelling health, social, and economic outcomes.
#
# Rules:
# - Use clear variable names and readable code.
# - Print intermediate outputs so your logic is easy to follow.
# - Keep one coherent workflow (reuse your objects instead of rebuilding from scratch each question).

# %% [markdown]
# ## Part A: StatsModels for Health and Social Outcome Modelling (Approx. 40 minutes)

# %% [markdown]
# ### Question 1: Imports and setup
#
# Import:
# - `numpy`, `pandas`, `matplotlib.pyplot`, `seaborn`
# - `statsmodels.api` and `statsmodels.formula.api`
#
# Set a reproducible random generator with seed 42.

# %%
# Answer 1

# %% [markdown]
# ### Question 2: Build a synthetic policy dataset
#
# Create a DataFrame called `health_df` with 20 areas and 12 months per area. Include these columns:
# - `area`, `month`
# - `median_income`, `deprivation_index`
# - `unemployment_rate`, `school_absence_rate`, `chronic_rate`
# - `preventive_visits`, `social_support_spend`, `winter`
# - `emergency_admissions_per_1k`
#
# Make the simulated data realistic for health, economic, and social analysis.

# %%
areas = [
    "Northside", "Central", "Riverside", "Eastbrook", "Hilltown",
    "Westgate", "Southdowns", "Moorfield", "Porthill", "Lakeside",
    "Greenlea", "Blakewell", "Ironbridge", "Briarwood", "Coldmoor",
    "Dunhollow", "Elmhaven", "Fernshaw", "Graymere", "Hartsend"
]

# %%
# Answer 2

# %% [markdown]
# ### Question 3: Quick diagnostics and risk label
#
# 1. Print dataset shape and first 5 rows.
# 2. Print descriptive stats for `emergency_admissions_per_1k`, `unemployment_rate`, `school_absence_rate`, and `median_income`.
# 3. Create `high_risk` as 1 if admissions are above the 70th percentile, else 0.
# 4. Print the class distribution of `high_risk`.

# %%
# Answer 3

# %% [markdown]
# ### Question 4: OLS model for emergency admissions
#
# Fit an OLS model predicting `emergency_admissions_per_1k` using:
# - `unemployment_rate`
# - `chronic_rate`
# - `school_absence_rate`
# - `preventive_visits`
# - `social_support_spend`
# - `winter`
# - `median_income`
# - `deprivation_index`
#
# Print the model summary.

# %%
# Answer 4

# %% [markdown]
# ### Question 5: Coefficients and model quality
#
# 1. Create a table with coefficients and p-values.
# 2. Sort by coefficient magnitude (largest absolute value first).
# 3. Compute and print MSE and R-squared using fitted values.

# %%
# Answer 5

# %% [markdown]
# ### Question 6: Diagnostics and scenario prediction
#
# 1. Create residual-vs-fitted and Q-Q plots.
# 2. Build 3 policy scenarios in a DataFrame (high stress, moderate intervention, stronger intervention).
# 3. Predict admissions for each scenario and print the results.

# %%
scenarios = pd.DataFrame([
    {"scenario": "High stress area (baseline)",
     "unemployment_rate": 0.15, "chronic_rate": 0.28, "school_absence_rate": 0.11,
     "preventive_visits": 12, "social_support_spend": 600, "winter": 0,
     "median_income": 25000, "deprivation_index": 65},
    {"scenario": "Moderate intervention",
     "unemployment_rate": 0.12, "chronic_rate": 0.24, "school_absence_rate": 0.09,
     "preventive_visits": 22, "social_support_spend": 900, "winter": 0,
     "median_income": 28000, "deprivation_index": 52},
    {"scenario": "Stronger intervention",
     "unemployment_rate": 0.08, "chronic_rate": 0.20, "school_absence_rate": 0.06,
     "preventive_visits": 35, "social_support_spend": 1400, "winter": 0,
     "median_income": 32000, "deprivation_index": 38},
])

# %%
# Answer 6

# %% [markdown]
# ## Part B: Scikit-learn for Risk Prediction and Segmentation (Approx. 45 minutes)

# %% [markdown]
# ### Question 7: Train/test split
#
# Using `health_df`, define:
# - `X` with the same predictors as Part A
# - `y` as `high_risk`
#
# Create a stratified train/test split (`test_size=0.30`, `random_state=42`).

# %%
# Answer 7

# %% [markdown]
# ### Question 8: Logistic regression pipeline
#
# 1. Standardize features using `StandardScaler`.
# 2. Fit a `LogisticRegression` model.
# 3. Generate class predictions and predicted probabilities for the test set.

# %%
# Answer 8

# %% [markdown]
# ### Question 9: Logistic evaluation
#
# Print:
# - accuracy
# - ROC AUC
# - confusion matrix (as a labeled DataFrame)
# - classification report

# %%
# Answer 9

# %% [markdown]
# ### Question 10: Random forest comparison
#
# 1. Fit a `RandomForestClassifier` (`n_estimators=300`, `max_depth=6`, `random_state=42`).
# 2. Evaluate on test data.
# 3. Build a comparison table of Logistic vs Random Forest (`accuracy`, `roc_auc`).

# %%
# Answer 10

# %% [markdown]
# ### Question 11: Threshold sensitivity for triage
#
# Using logistic predicted probabilities, evaluate thresholds `[0.30, 0.40, 0.50, 0.60]`.
# Create a table with:
# - threshold
# - precision
# - recall
#
# (Use `zero_division=0` where needed.)

# %%
# Answer 11

# %% [markdown]
# ### Question 12: Unsupervised area segmentation
#
# 1. Aggregate to one row per area (mean values).
# 2. Run KMeans with 3 clusters.
# 3. Create a scatter plot of `deprivation_index` vs `emergency_admissions_per_1k`, colored by cluster and sized by `median_income`.
# 4. Print the area-cluster table sorted by cluster.

# %%
# Answer 12

# %% [markdown]
# ## Part C: Text Modelling for Social and Public Health Notes (Approx. 30 minutes)

# %% [markdown]
# ### Question 13: Build and tokenize case notes
#
# Create a small list of at least 8 case notes related to social care, economic stress, and health service use.
#
# Then:
# 1. Tokenize with `wordpunct_tokenize`.
# 2. Lowercase and keep alphabetic tokens only.
# 3. Remove a small custom stopword set.
# 4. Print the first 30 cleaned tokens.

# %%
case_notes = [
    "Patient missed two appointments this month due to transport issues and reported housing arrears.",
    "Carer presenting with anxiety and exhaustion following recent welfare sanction affecting family income.",
    "Emergency attendance at A&E for chest pain; unemployed for several months and reports severe financial stress.",
    "School absence rate elevated in household; one child with chronic asthma, parent seeking benefits advice.",
    "Patient engaged with preventive programme; income stable, no significant risk factors identified.",
    "Recurring missed medications and inability to afford prescriptions on universal credit.",
    "High deprivation area resident; social worker referral noted, family experiencing debt and food insecurity.",
    "No concerns; regular attendance, employed, supportive family network, low social care need.",
    "Patient reported eviction notice and expressed suicidal ideation; urgent mental health referral made.",
    "Elderly resident isolated after bereavement; missed three appointments, chronic condition deteriorating.",
]

STOPWORDS = {"the", "a", "an", "and", "or", "in", "at", "to", "of", "with",
             "is", "was", "has", "for", "on", "this", "by", "that", "are",
             "no", "not", "it", "its", "their", "from", "due", "after",
             "following", "noted", "identified", "presenting", "be", "been"}

# %%
# Answer 13

# %% [markdown]
# ### Question 14: Frequency and collocations
#
# 1. Use `FreqDist` to print the 15 most common cleaned tokens.
# 2. Use `BigramCollocationFinder` to print 10 collocations.
# 3. Briefly identify 2 terms/pairs that could signal elevated social-health risk.

# %%
# Answer 14

# %% [markdown]
# ### Question 15: Rule-based triage scoring
#
# 1. Define a small keyword-to-weight dictionary (e.g. missed, arrears, sanction, anxiety, emergency).
# 2. Create a function to score each note.
# 3. Build a DataFrame with `note`, `risk_score`, and `priority` (`high` vs `routine`).
# 4. Sort by `risk_score` descending and print.

# %%
risk_keywords = {
    "missed":       2,
    "arrears":      3,
    "sanction":     3,
    "anxiety":      2,
    "emergency":    4,
    "stress":       2,
    "urgent":       4,
    "suicidal":     5,
    "eviction":     4,
    "prescription": 2,
    "isolated":     3,
    "insecurity":   3,
    "debt":         3,
    "deteriorating": 3,
    "crisis":       4,
    "chronic":      1,
    "absent":       1,
    "unemployed":   2,
    "medication":   2,
}

# %%
# Answer 15

# %% [markdown]
# ### Question 16: Visual communication of note-level risk
#
# Create a bar chart of triage `risk_score` by note index (or short label).
# Add title, axis labels, and readable x tick labels.
#
# Then print 2-3 lines identifying which notes should be prioritized first.

# %%
# Answer 16

# %% [markdown]
# ## Stretch (Optional)
#
# Build a short policy briefing table that combines:
# - top 3 high-risk areas from your predictive model
# - top 3 high-risk notes from your text scorer
#
# Write 3-4 lines proposing one targeted intervention strategy.
