# %% [markdown]
# # Python for Health, Social, and Economic Data Science
#
# ## Lab 3: Control Flow, Files, and NumPy
#
# This lab is longer and application-focused. Work through each question in order.
#
# Rules:
# - Use clear variable names and readable code.
# - Do not import external libraries beyond NumPy where requested.
# - Print intermediate outputs so your logic is easy to follow.

# %% [markdown]
# ## Part A: Control Flow, Pseudocode, and Functions

# %% [markdown]
# ### Question 1: While loop for service readiness
#
# Write a countdown using `while` for a vaccination clinic opening.
#
# The program should:
# 1. Take the number of minutes to opening as user input.
# 2. Validate that input is an integer.
# 3. Count down to zero.
# 4. Print `Clinic is open` at the end.

# %%
# Answer 1

# %% [markdown]
# ### Question 2: Pseudocode translation
#
# Write pseudocode (plain English steps) for this program:
#
# ```python
# def classify_income(value):
#     if value < 25000:
#         return "lower income"
#     elif value < 40000:
#         return "middle income"
#     else:
#         return "higher income"
#
# incomes = [22000, 31000, 42000]
# for inc in incomes:
#     print(inc, classify_income(inc))
# ```

# %%
# Answer 2

# %% [markdown]
# ### Question 3: Build a reusable text function
#
# Build a function that accepts a string and returns the number of unique letters (ignore spaces and punctuation).
#
# Use it on:
#
# ```python
# phrase_one = "Clinic demand is rising"
# phrase_two = "Income pressure affects health"
# ```
#
# Advanced: also return the number of capital letters.

# %%
# Answer 3

# %% [markdown]
# ### Question 4: Build a risk-label function
#
# Create a function `risk_label(absence_rate, unemployment_rate)` that returns:
# - `high risk` if absence_rate > 0.08 OR unemployment_rate > 0.12
# - `moderate risk` if absence_rate > 0.06 OR unemployment_rate > 0.09
# - `lower risk` otherwise
#
# Test it on at least 3 area examples.

# %%
# Answer 4

# %% [markdown]
# ## Part B: Files and Data Logging

# %% [markdown]
# ### Question 5: Write and count report lines
#
# Save the following text into a file named `../Data/mini_report.txt`:
#
# ```python
# mini_report = "Northside clinic visits are high\nCentral unemployment is stable\nRiverside school absence is elevated"
# ```
#
# Then read it back and count the number of lines programmatically.

# %%
# Answer 5

# %% [markdown]
# ### Question 6: Append and re-read
#
# Append one additional line to `../Data/mini_report.txt`:
# `Policy intervention starts next week`
#
# Then re-read the file and print:
# 1. Total number of lines
# 2. The last line only

# %%
# Answer 6

# %% [markdown]
# ## Part C: NumPy for Health, Social, and Economic Analysis

# %% [markdown]
# ### Question 7: NumPy basics with clinic visits
#
# Create a 1D NumPy array for weekly clinic visits:
# `[120, 95, 140, 102, 110, 87]`
#
# Then:
# - print total visits
# - print mean visits
# - print visits multiplied by 1.1 (a 10% demand increase scenario)

# %%
# Answer 7

# %% [markdown]
# ### Question 8: Rates per 1,000 population
#
# Given:
#
# ```python
# clinic_visits = np.array([120, 95, 140, 102, 110, 87])
# population = np.array([2400, 1800, 2600, 2100, 2000, 1700])
# ```
#
# Compute and print clinic visits per 1,000 residents for each area.

# %%
# Answer 8

# %% [markdown]
# ### Question 9: Matrix operations on area metrics
#
# Create a 2D NumPy array where each row is an area and columns are:
# 1. clinic_visits
# 2. school_absence_rate (as percent points, e.g. 7 for 0.07)
# 3. median_income (in thousands)
#
# Use this matrix:
#
# ```python
# A = np.array([[120, 7, 29],
#               [95, 5, 36],
#               [140, 9, 25]])
# ```
#
# Then:
# - add 1 to every absence value using broadcasting
# - multiply income column by 1.03
# - print updated matrix

# %%
# Answer 9

# %% [markdown]
# ### Question 10: PRNG with NumPy
#
# Set a seed and generate reproducible random draws:
#
# 1. 100 draws from a normal distribution for income shocks (`mean=0`, `sd=1500`)
# 2. 100 draws from an exponential distribution for time-to-readmission (`scale=30`)
# 3. Print the first 5 values from each

# %%
# Answer 10

# %% [markdown]
# ### Question 11: Income inequality (Gini coefficient)
#
# Implement a NumPy-based function to calculate the Gini coefficient for an income array.
#
# Use it on:
#
# ```python
# incomes_a = np.array([12000, 18000, 22000, 26000, 34000, 85000])
# incomes_b = np.array([22000, 24000, 25000, 26000, 27000, 29000])
# ```
#
# Print both Gini values and identify which area is more unequal.

# %%
# Answer 11

# %% [markdown]
# ### Question 12: Health economic cost function
#
# Model annual individual cost as:
#
# `cost = 450 + 120*age + 1500*chronic_conditions + 900*emergency_visits`
#
# Given:
#
# ```python
# age = np.array([35, 52, 47, 61, 29])
# chronic_conditions = np.array([0, 2, 1, 3, 0])
# emergency_visits = np.array([1, 0, 2, 3, 1])
# ```
#
# Tasks:
# 1. Compute and print individual costs
# 2. Compute and print mean cost
# 3. Recompute assuming emergency visits fall by 25% and print the mean saving

# %%
# Answer 12

# %% [markdown]
# ### Question 13 (Stretch): Monte Carlo policy scenario
#
# Using NumPy random draws, simulate 1,000 income shocks from a normal distribution and estimate:
# - proportion of shocks below `-2000`
# - proportion above `+2000`
#
# Print both proportions with clear labels.

# %%
# Answer 13
