# %% [markdown]
# # Python for Health, Social, and Economic Data Science
#
# ## Lab 1 (Estimated Duration: ~2 hours)
#
# This lab is designed for live coding and pair discussion. Work through each question in order.
#
# Guidelines:
# - Use clear variable names.
# - Do not import external libraries.
# - Print intermediate outputs so your reasoning is visible.
# - If you finish early, complete the stretch tasks.

# %% [markdown]
# ## Part A: Strings and Numbers (Approx. 30 minutes)

# %% [markdown]
# ### Question 1: Intro String
#
# Print one sentence introducing yourself and one health/social/economic indicator you are interested in.
#
# Example format:
# `I am Alex and I want to study school_absence_rate.`

# %%
# Answer 1
name = ""
indicator = ''

# %% [markdown]
# ### Question 2: Special Characters
#
# Write one line of code that prints exactly this block using `\n` and `\t` (no triple quotes):
#
# ```text
# Area: Northside
# 	Health indicator: clinic_visits
# 	Social indicator: school_absence_rate
# 	Economic indicator: median_income
# ```

# %%
# Answer 2

# %% [markdown]
# ### Question 3: Concatenation
#
# Using the variables below, print:
# `Northside | clinic_visits | school_absence_rate | median_income`
#
# ```python
# region = "Northside"
# health = "clinic_visits"
# social = "school_absence_rate"
# economic = "median_income"
# ```

# %%
region = "Northside"
health = "clinic_visits"
social = "school_absence_rate"
economic = "median_income"

# %%
# Answer 3

# %% [markdown]
# ### Question 4: String Methods
#
# Given:
#
# ```python
# s1 = "clinic visits"
# s2 = "SCHOOL ABSENCE RATE"
# s3 = "median_income"
# ```
#
# Tasks:
# 1. Print `s1` in title case.
# 2. Print `s2` in lower case.
# 3. Replace `_` with a space in `s3` and print it in title case.

# %%
s1 = "clinic visits"
s2 = "SCHOOL ABSENCE RATE"
s3 = "median_income"

# %%
# Answer 4

# %% [markdown]
# ### Question 5: Integer Operations
#
# Show **five different expressions** that each evaluate to `144`.
#
# Constraint: use at least four different operators across your five lines (e.g. `+`, `-`, `*`, `/`, `//`, `%`, `**`).

# %%
# Answer 5

# %% [markdown]
# ### Question 6: Floating Point and Formatting
#
# In one area, there were `37` absent students out of `512` students.
#
# Tasks:
# 1. Compute absence rate as a decimal.
# 2. Print the rate as a percentage with 2 decimal places (e.g. `7.23%`).

# %%
absent = 37
total = 512

# %%
# Answer 6

# %% [markdown]
# ## Part B: Lists and Dictionaries (Approx. 35 minutes)

# %% [markdown]
# ### Question 7: Build a Dictionary
#
# Create a dictionary named `northside` with the following key-value pairs:
# - `area`: `"Northside"`
# - `clinic_visits`: `120`
# - `school_absence_rate`: `0.07`
# - `median_income`: `29000`
#
# Print each value by querying its key.

# %%
# Answer 7

# %% [markdown]
# ### Question 8: Update and Extend a Dictionary
#
# Starting from:
#
# ```python
# central = {"area": "Central", "clinic_visits": 95, "median_income": 36000}
# ```
#
# Tasks:
# 1. Add `school_absence_rate` with value `0.05`.
# 2. Change `clinic_visits` from `95` to `102`.
# 3. Print the full dictionary.

# %%
central = {"area": "Central", "clinic_visits": 95, "median_income": 36000}

# %%
# Answer 8

# %% [markdown]
# ### Question 9: List Indexing and Slicing
#
# Given:
#
# ```python
# indicators = ["clinic_visits", "school_absence_rate", "median_income", "unemployment_rate", "rent_burden"]
# ```
#
# Tasks:
# 1. Print the first item.
# 2. Print the last item using negative indexing.
# 3. Print a slice containing only the two economic indicators.

# %%
indicators = ["clinic_visits", "school_absence_rate", "median_income",
              "unemployment_rate", "rent_burden"]

# %%
# Answer 9

# %% [markdown]
# ### Question 10: Reordering by Index
#
# Given:
#
# ```python
# wrong_order = ["Q3", "Q1", "Q4", "Q2"]
# ```
#
# Create a new list called `right_order` containing: `Q1, Q2, Q3, Q4` using only indexing.

# %%
wrong_order = ["Q3", "Q1", "Q4", "Q2"]

# %%
# Answer 10

# %% [markdown]
# ### Question 11: Split a Record String
#
# Given:
#
# ```python
# record = "Riverside|clinic_visits=140|school_absence_rate=0.09|median_income=25000"
# ```
#
# Tasks:
# 1. Split on `|` and print the resulting list.
# 2. Extract and print only the area name (`Riverside`).
# 3. Extract and print only the value for `median_income` as a string.

# %%
record = "Riverside|clinic_visits=140|school_absence_rate=0.09|median_income=25000"

# %%
# Answer 11

# %% [markdown]
# ### Question 12: Build a Snapshot from Parallel Lists
#
# Given:
#
# ```python
# areas = ["Northside", "Central", "Riverside"]
# clinic_visits = [120, 102, 140]
# school_absence_rate = [0.07, 0.05, 0.09]
# median_income = [29000, 36000, 25000]
# ```
#
# Create a dictionary called `central_snapshot` (for the second area only) with keys:
# `area`, `clinic_visits`, `school_absence_rate`, `median_income`.

# %%
areas = ["Northside", "Central", "Riverside"]
clinic_visits = [120, 102, 140]
school_absence_rate = [0.07, 0.05, 0.09]
median_income = [29000, 36000, 25000]

# %%
# Answer 12

# %% [markdown]
# ## Part C: Derived Indicators and Data Checks (Approx. 35 minutes)

# %% [markdown]
# ### Question 13: Derived Metric (Per 1,000)
#
# Given:
#
# ```python
# clinic_visits = [120, 102, 140]
# population = [2400, 3100, 2800]
# ```
#
# Compute and print clinic visits per 1,000 residents for each area (three separate print lines).

# %%
clinic_visits = [120, 102, 140]
population    = [2400, 3100, 2800]

# %%
# Answer 13

# %% [markdown]
# ### Question 14: Reporting Sentence
#
# Using values from `central_snapshot` (from Q12), print one sentence:
#
# `Central recorded X clinic visits, Y% absence, and median income Z.`
#
# Format `Y` to 1 decimal place in percent units.

# %%
central_snapshot = {
    "area": "Central", "clinic_visits": 102,
    "school_absence_rate": 0.05, "median_income": 36000
}

# %%
# Answer 14

# %% [markdown]
# ### Question 15: Clean Messy Indicator Names
#
# Given:
#
# ```python
# raw = [" Clinic_Visits ", "school_absence_rate", " MEDIAN_INCOME"]
# ```
#
# Create and print a new list where each item is:
# - stripped of surrounding whitespace
# - converted to lower case
# - underscores replaced by spaces

# %%
raw = [" Clinic_Visits ", "school_absence_rate", " MEDIAN_INCOME"]

# %%
# Answer 15

# %% [markdown]
# ### Question 16: Type Conversion Check
#
# Given string inputs:
#
# ```python
# visits_str = "140"
# absence_str = "0.09"
# income_str = "25000"
# ```
#
# Tasks:
# 1. Convert each to the most appropriate numeric type.
# 2. Print each converted value and its type using `type(...)`.

# %%
visits_str = "140"
absence_str = "0.09"
income_str = "25000"

# %%
# Answer 16

# %% [markdown]
# ### Question 17: Build a Nested Dictionary
#
# Build a dictionary called `area_profiles` with keys `Northside`, `Central`, and `Riverside`.
# Each key should map to a sub-dictionary containing:
# - `clinic_visits`
# - `school_absence_rate`
# - `median_income`
#
# Use the values from earlier questions.

# %%
# Answer 17

# %% [markdown]
# ### Question 18: Query and Compare
#
# Using `area_profiles`:
# 1. Print Riverside's school absence rate.
# 2. Print the difference in median income between Central and Riverside.
# 3. Print the sum of clinic visits for Northside and Central.

# %%
# Answer 18

# %% [markdown]
# ## Part D: Integrated Mini-Case (Approx. 20-30 minutes)

# %% [markdown]
# ### Question 19: Mini Case Setup
#
# Create this list of dictionaries:
#
# ```python
# mini_data = [
#     {"area": "Northside", "clinic_visits": 120, "school_absence_rate": 0.07, "median_income": 29000},
#     {"area": "Central", "clinic_visits": 102, "school_absence_rate": 0.05, "median_income": 36000},
#     {"area": "Riverside", "clinic_visits": 140, "school_absence_rate": 0.09, "median_income": 25000}
# ]
# ```
#
# Then print:
# 1. The full record for Central.
# 2. The median income for Northside.
# 3. The clinic visits for Riverside.

# %%
mini_data = [
    {"area": "Northside", "clinic_visits": 120, "school_absence_rate": 0.07, "median_income": 29000},
    {"area": "Central",   "clinic_visits": 102, "school_absence_rate": 0.05, "median_income": 36000},
    {"area": "Riverside", "clinic_visits": 140, "school_absence_rate": 0.09, "median_income": 25000},
]

# %%
# Answer 19

# %% [markdown]
# ### Question 20: One-Line Summary Builder
#
# Build and print a summary for Central in this style:
#
# `Central | visits: 102 | absence: 5.0% | income: 36000`
#
# Constraint: build at least part of the output by joining a list of strings with `' | '.join(...)`.

# %%
central = mini_data[1]

# %%
# Answer 20

# %% [markdown]
# ### Question 21 (Stretch): Debugging and Refactor
#
# This code has multiple problems. Fix it so it prints a correct sentence and uses meaningful variable names:
#
# ```python
# Area = "Riverside"
# clinic_visits = "140"
# print(area + " visits next month: " + clinic_visits + 5)
# ```
#
# After fixing, print:
# `Riverside visits next month: 145`

# %%
Area = "Riverside"
clinic_visits = "140"
print(area + " visits next month: " + clinic_visits + 5)

# %%
# Answer 21 (Stretch)

# %% [markdown]
# ## End of Lab Checklist
#
# Before class ends, make sure you have:
# - attempted every core question (1-20),
# - marked any blockers with a short comment,
# - identified one question to review live at the start of next class.
