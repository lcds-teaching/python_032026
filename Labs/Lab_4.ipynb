# %% [markdown]
# # Python for Health, Social, and Economic Data Science
#
# ## Lab 4: Data Access, Pandas, and Matplotlib
#
# This lab is based on Lecture 4. It is fully applied to health, social, and economic data science.
#
# Rules:
# - Use clear variable names.
# - Add short comments where useful.
# - Print intermediate outputs to show your logic.

# %% [markdown]
# ## Part A: Requests and JSON (Applied Data Access)

# %% [markdown]
# ### Question 1: Basic GET request
#
# Use `requests.get` to download this World Bank indicator as JSON:
#
# ```python
# url = "https://api.worldbank.org/v2/country/all/indicator/SP.DYN.LE00.IN?format=json&per_page=200"
# ```
#
# Then print:
# 1. the response type
# 2. the status code
# 3. the first 200 characters of `response.text`

# %%
# Answer 1

# %% [markdown]
# ### Question 2: Parse JSON and inspect data
#
# From the same response:
# 1. Parse JSON with `.json()`
# 2. Confirm its top-level type
# 3. Print the first observation where `value` is not null (country, year, value).

# %%
# Answer 2

# %% [markdown]
# ### Question 3: Requests with parameters
#
# Repeat Question 1 using `params=` instead of putting query arguments directly in the URL.
#
# Use:
# ```python
# base_url = "https://api.worldbank.org/v2/country/all/indicator/NY.GDP.PCAP.CD"
# params = {"format": "json", "per_page": 100}
# ```
#
# Print the final URL (`response.url`) and status code.

# %%
# Answer 3

# %% [markdown]
# ### Question 4: Error handling with requests
#
# Create a small `try/except` block around a request to a broken endpoint (e.g. add a typo in the URL path).
#
# Print a clear message if JSON parsing fails or if the status code is not 200.

# %%
# Answer 4

# %% [markdown]
# ## Part B: Pandas for Policy Data

# %% [markdown]
# ### Question 5: Build a health/social/economic dashboard dataframe
#
# Create a pandas DataFrame called `dashboard_df` with these columns:
# - `area`
# - `region_type` (Urban/Suburban/Rural)
# - `clinic_visits`
# - `school_absence_rate`
# - `median_income`
# - `unemployment_rate`
# - `population`
#
# Use at least 8 rows of made-up but realistic values. Print the first 5 rows.

# %%
# Answer 5

# %% [markdown]
# ### Question 6: Derived indicators
#
# Using `dashboard_df`, create:
# 1. `visits_per_1000` = clinic_visits / population * 1000
# 2. `economic_stress_index` = unemployment_rate * (1 / median_income) * 1_000_000
#
# Print `area`, `visits_per_1000`, and `economic_stress_index`.

# %%
# Answer 6

# %% [markdown]
# ### Question 7: Filtering and sorting
#
# Create a filtered table of areas where:
# - `school_absence_rate > 0.08` OR
# - `unemployment_rate > 0.12`
#
# Sort descending by `school_absence_rate` and print the result.

# %%
# Answer 7

# %% [markdown]
# ### Question 8: Groupby summaries
#
# Group by `region_type` and compute:
# - mean clinic visits
# - mean school absence rate
# - mean median income
#
# Print the grouped table.

# %%
# Answer 8

# %% [markdown]
# ### Question 9: Merge with policy budget data
#
# Create a second dataframe called `budget_df` with columns:
# - `area`
# - `public_health_budget`
#
# Merge it with `dashboard_df` on `area` and print the merged result.

# %%
# Answer 9

# %% [markdown]
# ### Question 10: Save and reload
#
# Save your merged dataframe to `../Data/health_social_econ_dashboard.csv`, then load it back with pandas and print `head()`.

# %%
# Answer 10

# %% [markdown]
# ## Part C: Matplotlib for Communication

# %% [markdown]
# ### Question 11: Line chart
#
# Build a line chart of monthly clinic visits for two areas (`Northside`, `Riverside`) over 6 months.
#
# Requirements:
# - title
# - axis labels
# - legend
# - grid

# %%
# Answer 11

# %% [markdown]
# ### Question 12: Scatter chart with annotation
#
# Using `dashboard_df`, make a scatter plot:
# - x: unemployment_rate
# - y: school_absence_rate
# - marker size: clinic_visits
#
# Annotate each point with area name.

# %%
# Answer 12

# %% [markdown]
# ### Question 13: Bar + histogram
#
# Create one figure with 2 subplots:
# 1. bar chart of `median_income` by `area`
# 2. histogram of `unemployment_rate`
#
# Use readable axis labels and subplot titles.

# %%
# Answer 13

# %% [markdown]
# ### Question 14: Combined policy dashboard figure
#
# Build a 2x2 matplotlib dashboard using your own choices from the variables you created.
#
# Example combination:
# - clinic visits trend
# - absence vs unemployment scatter
# - visits_per_1000 by area
# - distribution of median income
#
# Finish with `plt.tight_layout()`.

# %%
# Answer 14

# %% [markdown]
# ## Stretch (Optional)
#
# Create one extra figure that compares an equity-related metric (e.g., visits_per_1000 or school_absence_rate) across area groups, and write 2-3 lines interpreting it.
